# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt


# f(x) = 1/sqrt(x) x E [1;10]

x = np.linspace(1,10,200).reshape(-1, 1)

X = np.hstack([x, np.sqrt(x), np.log(x), 1 / x, x**2])

f = 1 / np.sqrt(x)
y = np.hstack([f, f**2, np.sqrt(f)])

model = Sequential(
    [
        Dense(64, activation="relu", input_shape=(5,)),
        Dense(32, activation="relu"),
        Dense(3), 
    ]
)

model.compile(optimizer="adam", loss="mse")
model.fit(X, y, epochs=131, batch_size=32, verbose=1)

y_pred = model.predict(X)

plt.figure(figsize=(7, 6))
plt.scatter(y[:, 0], y_pred[:, 0], color="blue", alpha=0.6)
plt.plot([0, 1], [0, 1], "r--", lw=2)
plt.title("Przewidywanie f(x)=1/sqrt(x)")
plt.xlabel("Prawdziwa wartość (f(x))")
plt.ylabel("Wartość przywidywana")
plt.grid(True)
plt.show()
# Out:
# Epoch 1/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 30.2023
# Epoch 2/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2782
# Epoch 3/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9753
# Epoch 4/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5357
# Epoch 5/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1902
# Epoch 6/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2699
# Epoch 7/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1790
# Epoch 8/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0658
# Epoch 9/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0827
# Epoch 10/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0418
# Epoch 11/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0353
# Epoch 12/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0219
# Epoch 13/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215
# Epoch 14/131
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0170
# Epoch 15/131
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# f(x) = 1/sqrt(x) x E [1;10]

X = np.linspace(1, 10,).reshape(-1, 1)
y = 1 / np.sqrt(X)

model = Sequential(
    [
        Dense(64, activation="relu", input_shape=(1,)),
        Dense(32, activation="relu"),
        Dense(1), 
    ]
)

model.compile(optimizer="adam", loss="mse")
history = model.fit(X, y, epochs=131, batch_size=32, verbose=1)

y_pred = model.predict(X)

plt.figure(figsize=(7, 6))
plt.scatter(y, y_pred, color="blue", alpha=0.6)
plt.plot([0, 1], [0, 1], "r--", lw=2)
plt.title("Regresja f(x)=1/sqrt(x)")
plt.xlabel("Wartość rzeczywista f(x)")
plt.ylabel("Wartość przewidywana")
plt.grid(True)
plt.show()

mse_fn = tf.keras.losses.MeanSquaredError()
mse = mse_fn(y, y_pred).numpy()

print(f"\nMean Squared Error: {mse:.5f}")
# Out:
# Epoch 1/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.3560
# Epoch 2/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1897
# Epoch 3/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1357
# Epoch 4/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1395
# Epoch 5/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1695
# Epoch 6/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1635
# Epoch 7/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1402
# Epoch 8/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1311
# Epoch 9/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1070
# Epoch 10/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1128
# Epoch 11/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1241
# Epoch 12/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1230
# Epoch 13/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1162
# Epoch 14/131
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1127
# Epoch 15/131
# ...
